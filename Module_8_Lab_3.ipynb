# %% [markdown]
# <a href="https://colab.research.google.com/github/GLmounika/FMML-MODULE2-LAB1/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-12 00:09:40--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  57.0MB/s    in 1.2s
#
# 2024-04-12 00:09:45 (57.0 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3527   1711.02329v1  Convolutional neural networks (CNNs) achieve s...  stat
# 10252   0908.0050v2  Sparse coding--that is, modelling data vectors...  stat
# 6716   1705.08056v1  Construction of ambiguity set in robust optimi...  stat
# 27632  1704.01264v1  All people with diabetes have the risk of deve...    cs
# 25552  1510.00981v3  Real-time hand articulations tracking is impor...    cs
# ...             ...                                                ...   ...
# 2568   1605.07079v2  Bayesian optimization has become a successful ...    cs
# 22379  1605.02541v2  We study in this paper the consequences of usi...  stat
# 3380   1607.06011v1  Next generation deep neural networks for class...    cs
# 26072  1608.05246v1  Face recognition approaches that are based on ...    cs
# 2256   1711.01244v3  In meta-learning an agent extracts knowledge f...  stat
#
#                                                    title  year  \
# 3527   Interpreting Convolutional Neural Networks Thr...  2017
# 10252  Online Learning for Matrix Factorization and S...  2009
# 6716   Ambiguity set and learning via Bregman and Was...  2017
# 27632  Classification of Diabetic Retinopathy Images ...  2017
# 25552  Efficient Hand Articulations Tracking using Ad...  2015
# ...                                                  ...   ...
# 2568   Fast Bayesian Optimization of Machine Learning...  2016
# 22379  Mean Absolute Percentage Error for regression ...  2016
# 3380   On the Modeling of Error Functions as High Dim...  2016
# 26072  How Image Degradations Affect Deep CNN-based F...  2016
# 2256   Meta-Learning by Adjusting Priors Based on Ext...  2017
#
#                                                 keywords
# 3527   [convolutional, performance, interpreting, cha...
# 10252  [modelling, combinations, neuroscience, proces...
# 6716   [construction, ambiguity, optimization, diverg...
# 27632  [developing, retinopathy, threatening, complic...
# 25552  [articulations, important, applications, inter...
# ...                                                  ...
# 2568   [optimization, successful, hyperparameter, opt...
# 22379  [consequences, percentage, regression, existen...
# 3380   [generation, classification, platforms, effici...
# 26072  [recognition, approaches, convolutional, domin...
# 2256   [knowledge, facilitate, assumption, representa...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3527     [convolutional, performance, interpreting, cha...
# 10252    [modelling, combinations, neuroscience, proces...
# 6716     [construction, ambiguity, optimization, diverg...
# 27632    [developing, retinopathy, threatening, complic...
# 25552    [articulations, important, applications, inter...
#                                ...
# 25681    [attractiveness, developed, automatic, percept...
# 5371     [efficient, algorithms, introduce, understood,...
# 32734    [difficult, algorithms, prognosis, searching, ...
# 11616    [interesting, concentrate, dimensional, manifo...
# 6258     [determinantal, processes, manipulated, infere...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8780 words.
# Out of those 4601 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="855d3528-08cb-454a-b1a2-fd9c3cb20c39" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("855d3528-08cb-454a-b1a2-fd9c3cb20c39")) {                    Plotly.newPlot(                        "855d3528-08cb-454a-b1a2-fd9c3cb20c39",                        [{"x":["particularly","classification","quantifies","important","reduction","challenge","convolutional","compressed","interpretation","recognition","selectivity","introduce","demonstrate","redundant","specifically","algorithm","selective","investigate","parameters","importance","iteratively","consistent","interpreting","structural","interpretability","meaningful","compression","visualized","performance","dictionary","experiments","variations","modelling","principal","optimization","combinations","neuroscience","component","gracefully","formulations","factorization","approximations","processing","stochastic","demonstrating","naturally","statistics","presented","convergence","wasserstein","concentration","ambiguity","generalization","appropriate","statistical","asymmetric","designing","classical","construction","functions","divergences","probability","objective","asymptotic","divergence","distribution","approximating","distributions","outperforms","automatic","including","performed","different","retinopathy","spectrally","improving","promising","approaches","detection","developing","framework","generally","performing","dimensionality","recognizing","diagnosis","comparison","concerned","treatment","localized","extensive","occurrence","complication","potential","generated","expensive","adjustment","computations","generating","inappropriate","algorithms","knowledge","hierarchical","discrepancy","initialize","augmented","articulations","initialization","interacting","contributions","efficient","consuming","consequently","minimizing","personalized","applications","segmented","challenging","configurations","programming","concurrent","extraction","untrimmed","proposals","foreground","background","associates","temporally","maximisation","associate","advantage","segmentation","segmentations","localisation","simplified","penalties","interested","estimates","previously","environment","government","combination","complexity","solutions","understand","approximate","techniques","empirical","reinforcement","determining","recommendations","controlled","effective","assumption","analytical","determine","understanding","calculate","tractable","posterior","normalizing","variables","multiplicative","auxiliary","significantly","approximation","employing","straightforward","variational","predictive","uncertainty","reparametrizations","attracted","constraints","information","sentences","constructing","grounding","regression","representations","retrieving","structure","embedding","consideration","similarity","localization","accuracies","directional","modalities","attention","investigates","neighborhood","structures","retrieval","intermediate","standardize","feedforward","computationally","procedure","sequential"],"y":[75,494,4,345,111,131,377,27,52,348,2,332,602,20,172,813,13,137,245,71,31,81,11,70,19,46,50,7,865,58,587,74,53,25,328,34,12,86,0,27,36,28,281,139,33,60,59,182,113,5,14,13,115,69,166,14,57,96,67,233,7,170,177,23,15,224,11,100,253,161,257,125,717,3,3,104,134,438,335,62,575,64,76,56,23,54,139,23,42,16,152,34,1,141,158,78,15,38,98,6,587,373,91,15,3,29,3,24,15,51,417,27,36,47,13,426,27,239,22,123,5,129,7,26,21,78,5,12,2,8,88,198,17,5,23,3,27,75,88,110,7,135,257,142,75,104,386,144,123,30,16,36,247,65,31,64,140,21,18,39,2,119,19,20,271,110,21,14,47,54,69,0,23,135,707,76,34,12,112,239,14,333,103,27,158,64,26,22,32,152,24,21,150,105,39,3,21,59,115,83],"type":"bar"},{"x":["particularly","classificat ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4601,), (4601, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Plan</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Explicability</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>Predictability</span> <span style=''>for</span> <span style=''>Robot</span> <span style=''>Task</span> <span style=''>Planning</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.7878787878787878);'>Intelligent</span> <span style=''>robots</span> <span style=''>and</span> <span style=''>machines</span> <span style=''>are</span> <span style=''>becoming</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>pervasive</span> <span style=''>in</span> <span style=''>human</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>populated</span> <span style='background-color:rgba(0, 255, 0, 0.4915254237288136);'>environments</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>desirable</span> <span style='background-color:rgba(0, 255, 0, 0.5362318840579711);'>capability</span> <span style=''>of</span> <span style=''>these</span> <span style=''>agents</span> <span style=''>is</span> <span style=''>to</span> <span style=''>respond</span> <span style=''>to</span> <span style=''>goal</span> <span style=''>oriented</span> <span style=''>commands</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>autonomously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructing</span> <span style=''>task</span> <span style=''>plans</span> <span style=''>However</span> <span style=''>such</span> <span style=''>autonomy</span> <span style=''>can</span> <span style=''>add</span> <span style='background-color:rgba(0, 255, 0, 0.31233595800524927);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.5625);'>cognitive</span> <span style=''>load</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potentially</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>safety</span> <span style=''>risks</span> <span style=''>to</span> <span style=''>humans</span> <span style=''>when</span> <span style=''>agents</span> <span style=''>behave</span> <span style=''>unexpectedly</span> <span style=''>Hence</span> <span style=''>for</span> <span style=''>such</span> <span style=''>agents</span> <span style=''>to</span> <span style=''>be</span> <span style=''>helpful</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>requirement</span> <span style=''>is</span> <span style=''>for</span> <span style=''>them</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857143);'>synthesize</span> <span style=''>plans</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>easily</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understood</span> <span style=''>by</span> <span style=''>humans</span> <span style=''>While</span> <span style=''>there</span> <span style=''>exists</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>that</span> <span style=''>studied</span> <span style=''>socially</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>acceptable</span> <span style=''>robots</span> <span style=''>that</span> <span style=''>interact</span> <span style=''>with</span> <span style=''>humans</span> <span style=''>in</span> <span style=''>natural</span> <span style=''>ways</span> <span style=''>and</span> <span style=''>work</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigated</span> <span style=''>legible</span> <span style=''>motion</span> <span style=''>planning</span> <span style=''>there</span> <span style=''>lacks</span> <span style=''>a</span> <span style=''>general</span> <span style=''>solution</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>outcome</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>forward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stagewise</span> <span style=''>approach</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>method</span> <span style=''>of</span> <span style=''>variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situation</span> <span style=''>where</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinearly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>outcome</span> <span style=''>variable</span> <span style=''>The</span> <span style=''>method</span> <span style=''>doesnt</span> <span style=''>assume</span> <span style=''>any</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>form</span> <span style=''>and</span> <span style=''>can</span> <span style=''>select</span> <span style=''>from</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>candidates</span> <span style=''>It</span> <span style=''>takes</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incremental</span> <span style=''>forward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stagewise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>in</span> <span style=''>which</span> <span style=''>very</span> <span style=''>small</span> <span style=''>steps</span> <span style=''>are</span> <span style=''>taken</span> <span style=''>to</span> <span style=''>select</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>Given</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>form</span> <span style=''>is</span> <span style=''>assumed</span> <span style=''>we</span> <span style=''>devised</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>termed</span> <span style=''>roughening</span> <span style=''>to</span> <span style=''>adjust</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>residuals</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterations</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>we</span> <span style=''>show</span> <span style=''>the</span> <span style=''>new</span> <span style=''>method</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style=''>against</span> <span style=''>popular</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Robot</span> <span style=''>Location</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Situation</span> <span style=''>Calculus</span> <br/><br/><span style=''>Location</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>sensing</span> <span style=''>task</span> <span style=''>in</span> <span style=''>robotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>where</span> <span style=''>the</span> <span style=''>world</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.49999999999999994);'>uncertain</span> <span style=''>and</span> <span style=''>sensors</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectors</span> <span style=''>are</span> <span style=''>noisy</span> <span style=''>Most</span> <span style=''>systems</span> <span style=''>make</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.34782608695652173);'>assumptions</span> <span style=''>about</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>between</span> <span style=''>state</span> <span style='background-color:rgba(255, 0, 0, 0.4292565947242207);'>variables</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>about</span> <span style=''>how</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependencies</span> <span style=''>change</span> <span style=''>as</span> <span style=''>a</span> <span style=''>result</span> <span style=''>of</span> <span style=''>actions</span> <span style=''>Building</span> <span style=''>on</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>by</span> <span style=''>Bacchus</span> <span style=''>Halpern</span> <span style=''>and</span> <span style=''>Levesque</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.7999999999999999);'>reasoning</span> <span style=''>about</span> <span style=''>degrees</span> <span style=''>of</span> <span style=''>belief</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situation</span> <span style=''>calculus</span> <span style=''>and</span> <span style=''>a</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>to</span> <span style=''>it</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>domains</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>illustrate</span> <span style=''>location</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>rich</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>actions</span> <span style=''>using</span> <span style=''>an</span> <span style=''>example</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>that</span> <span style=''>while</span> <span style=''>actions</span> <span style=''>might</span> <span style=''>affect</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.39209726443768994);'>distributions</span> <span style=''>in</span> <span style='background-c ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>DyNet</span> <span style=''>The</span> <span style=''>Dynamic</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>Toolkit</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style=''>DyNet</span> <span style=''>a</span> <span style=''>toolkit</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementing</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>models</span> <span style=''>based</span> <span style=''>on</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>declaration</span> <span style=''>of</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>In</span> <span style=''>the</span> <span style=''>static</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>declaration</span> <span style=''>strategy</span> <span style=''>that</span> <span style=''>is</span> <span style=''>used</span> <span style=''>in</span> <span style=''>toolkits</span> <span style=''>like</span> <span style=''>Theano</span> <span style=''>CNTK</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>TensorFlow</span> <span style=''>the</span> <span style=''>user</span> <span style=''>first</span> <span style=''>defines</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>graph</span> <span style=''>(a</span> <span style=''>symbolic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>computation)</span> <span style=''>and</span> <span style=''>then</span> <span style=''>examples</span> <span style=''>are</span> <span style=''>fed</span> <span style=''>into</span> <span style=''>an</span> <span style=''>engine</span> <span style=''>that</span> <span style=''>executes</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>and</span> <span style=''>computes</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>derivatives</span> <span style=''>In</span> <span style=''>DyNets</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>declaration</span> <span style=''>strategy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>is</span> <span style=''>mostly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transparent</span> <span style=''>being</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implicitly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>executing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedural</span> <span style=''>code</span> <span style=''>that</span> <span style=''>computes</span> <span style=''>the</span> <span style=''>network</span> <span style=''>outputs</span> <span style=''>and</span> <span style=''>the</span> <span style=''>user</span> <span style=''>is</span> <span style=''>free</span> <span style=''>to</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>for</span> <span style=''>each</span> <span style=''>input</span> <span style=''>Dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>declaration</span> <span style=''>thus</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>facilitates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implementation</span> <sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.07148014440433213)
# 	experimental (0.1447653429602888)
# 	architecture (0.09169675090252707)
# 	knowledge (0.13465703971119133)
# 	representation (0.13971119133574006)
# 	detection (0.12093862815884476)
# 	different (0.2588447653429603)
# 	information (0.2552346570397112)
# 	recognition (0.1256317689530686)
# 	convolutional (0.13610108303249097)
#
# Some Statistics words are:
# 	variational (0.0980295566502463)
# 	stochastic (0.1354679802955665)
# 	algorithm (0.3847290640394089)
# 	estimation (0.17339901477832512)
# 	distribution (0.17536945812807883)
# 	theoretical (0.15517241379310345)
# 	variables (0.14679802955665025)
# 	dimensional (0.1832512315270936)
# 	inference (0.2019704433497537)
# 	regression (0.1896551724137931)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="29a69757-4bc7-4531-8932-20f8530257a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("29a69757-4bc7-4531-8932-20f8530257a5")) {                    Plotly.newPlot(                        "29a69757-4bc7-4531-8932-20f8530257a5",                        [{"x":["particularly","classification","quantifies","important","reduction","challenge","convolutional","compressed","interpretation","recognition","selectivity","introduce","demonstrate","redundant","specifically","algorithm","selective","investigate","parameters","importance","iteratively","consistent","interpreting","structural","interpretability","meaningful","compression","visualized","performance","dictionary","experiments","variations","modelling","principal","optimization","combinations","neuroscience","component","gracefully","formulations","factorization","approximations","processing","stochastic","demonstrating","naturally","statistics","presented","convergence","wasserstein","concentration","ambiguity","generalization","appropriate","statistical","asymmetric","designing","classical","construction","functions","divergences","probability","objective","asymptotic","divergence","distribution","approximating","distributions","outperforms","automatic","including","performed","different","retinopathy","spectrally","improving","promising","approaches","detection","developing","framework","generally","performing","dimensionality","recognizing","diagnosis","comparison","concerned","treatment","localized","extensive","occurrence","complication","potential","generated","expensive","adjustment","computations","generating","inappropriate","algorithms","knowledge","hierarchical","discrepancy","initialize","augmented","articulations","initialization","interacting","contributions","efficient","consuming","consequently","minimizing","personalized","applications","segmented","challenging","configurations","programming","concurrent","extraction","untrimmed","proposals","foreground","background","associates","temporally","maximisation","associate","advantage","segmentation","segmentations","localisation","simplified","penalties","interested","estimates","previously","environment","government","combination","complexity","solutions","understand","approximate","techniques","empirical","reinforcement","determining","recommendations","controlled","effective","assumption","analytical","determine","understanding","calculate","tractable","posterior","normalizing","variables","multiplicative","auxiliary","significantly","approximation","employing","straightforward","variational","predictive","uncertainty","reparametrizations","attracted","constraints","information","sentences","constructing","grounding","regression","representations","retrieving","structure","embedding","consideration","similarity","localization","accuracies","directional","modalities","attention","investigates","neighborhood","structures","retrieval","intermediate","standardize","feedforward","computationally","procedure","sequential","normalized","difficult","beneficial","particular","criterion","recurrent","normalization","parallelize","dependencies","transitions","designers","illustrated","practically","discussed","dependent","connected","described","obtaining","programmers","intrusion","multiplatform","direction","application","fundamental","exclusively","attacking","reference","coordinate","separable","arbitrary","technique","differences","resulting","supervised","preceding","empirically","unnoticed","simultaneous","carefully","converging","generalize","differentiable","candidates","estimation","estimations","identified","multivariate","selection","integrated","bandwidth","derivative","expression","estimator","elementar ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	gracefully
# 	reparametrizations
# 	marginalization
# 	uhlenbeck
# 	asymptotics
# 	stabilisation
# 	disability
# 	inflation
# 	connectomics
# 	unnormalized
# 	attackers
# 	byzantine
# 	confounders
# 	confounding
# 	faithfulness
# 	subgaussian
# 	sridharan
# 	staleness
# 	overconfident
# 	regulating
# Some words which never appear in Statistics papers:
# 	retinopathy
# 	spectrally
# 	articulations
# 	untrimmed
# 	associate
# 	government
# 	grounding
# 	designers
# 	programmers
# 	roughness
# 	chronological
# 	achievements
# 	unmoderated
# 	infographics
# 	luminance
# 	chrominance
# 	descriptiveness
# 	reactions
# 	informing
# 	coreference

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0958793845391784e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
